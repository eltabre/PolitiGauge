# %%
import json, pandas as pd
from pandas.io.json import json_normalize


df = pd.read_json('AllSidesSources.json')

df
# Out:
#                     courier-journal.com              cadizrecord.com  \
# rating                        Lean Left                    Lean Left
# title        Louisville Courier-Journal             The Cadiz Record
# url     http://www.courier-journal.com/  http://www.cadizrecord.com/
#
#                          delcotimes.com              theepochtimes.com  \
# rating                        Lean Left                     Lean Right
# title   The Delaware County Daily Times                The Epoch Times
# url          http://www.delcotimes.com/  https://www.theepochtimes.com
#
#                        theguardian.com               theflipside.io  \
# rating                       Lean Left                        Mixed
# title                     The Guardian                The Flip Side
# url     https://www.theguardian.com/us  https://www.theflipside.io/
#
#                    observer.com              telegraph.co.uk  \
# rating                   Center                   Lean Right
# ...

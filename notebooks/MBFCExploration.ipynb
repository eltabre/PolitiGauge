# %%
import json, pandas as pd
from pandas.io.json import json_normalize


df = pd.read_json('MBFCsourcesAll.json')
dfStripped = df.loc[["bias","name","reporting","notes"], :]

dfStripped
# Out:
#                                          100percentfedup.com  \
# bias                                               fake-news
# name                                      100 Percent Fed Up
# reporting                                               FAKE
# notes      100 Percent Fed Up is a news website and blog ...
#
#                                                   10news.one  \
# bias                                               fake-news
# name                                              10News.one
# reporting                                               FAKE
# notes      10News.one is a far-right news, opinion and co...
#
#                                                180report.com  \
# bias                                                  center
# name                                               OneEighty
# reporting                                              MIXED
# notes      OneEighty or 180Report.com is a news aggregati...
#
#           21stcenturywire.com  \
# ...
